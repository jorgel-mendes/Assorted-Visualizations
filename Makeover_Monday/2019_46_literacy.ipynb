# %% [markdown]
# # 2019/W46: 2019/W46: Youth & adult literacy rates
#
# Data from [here](https://data.world/makeovermonday/2019w46)
#
# # Load packages and import data

# %%
import pandas as pd
import altair as alt
from vega_datasets import data

# %%
world = alt.topo_feature(data.world_110m.url, feature='countries')

# US states background
background = alt.Chart(world).mark_geoshape(
    fill='lightgray',
    stroke='white'
).properties(
    width=500,
    height=300
).project('equirectangular'
).configure(
    background='snow'
)

background
# Out:
# alt.Chart(...)

# %%
df = pd.read_excel('https://query.data.world/s/q5g76ayqd352pmacm4zxekyhq3rx5c')
df.head()
# Out:
#                       Region      Country  Year    Age  Gender  Literacy rate
# 0  Central and Southern Asia  Afghanistan  2011    15+  female       0.176121
# 1  Central and Southern Asia  Afghanistan  2011    15+    male       0.454171
# 2  Central and Southern Asia  Afghanistan  2011    15+   total       0.317411
# 3  Central and Southern Asia  Afghanistan  2011  15-24  female       0.321132
# 4  Central and Southern Asia  Afghanistan  2011  15-24    male       0.618791

# %% [markdown]
# Yes, except for the current one, 2019.
#
# And a quick `describe`.

# %%
df.describe(include='all')
# Out:
#                                  Region  Country         Year   Age Gender  \
# count                              4955     4955  4955.000000  4955   4955
# unique                                7      155          NaN     4      3
# top     Latin America and the Caribbean  Uruguay          NaN   15+  total
# freq                               1410      108          NaN  1260   1652
# mean                                NaN      NaN  2013.987891   NaN    NaN
# std                                 NaN      NaN     2.746204   NaN    NaN
# min                                 NaN      NaN  2010.000000   NaN    NaN
# 25%                                 NaN      NaN  2011.000000   NaN    NaN
# 50%                                 NaN      NaN  2014.000000   NaN    NaN
# 75%                                 NaN      NaN  2016.000000   NaN    NaN
# max                                 NaN      NaN  2018.000000   NaN    NaN
#
#         Literacy rate
# count     4955.000000
# ...

# %% [markdown]
# Some numeric values are not in the right type. So I'll take a look and transform them.

# %%
from vega_datasets import data

# %%
# ?alt.topo_feature
# Out:
# Signature: alt.topo_feature(url, feature, **kwargs)
# Docstring:
# A convenience function for extracting features from a topojson url
#
# Parameters
# ----------
# url : string
#     An URL from which to load the data set.
#
# feature : string
#     The name of the TopoJSON object set to convert to a GeoJSON feature collection. For
#     example, in a map of the world, there may be an object set named `"countries"`.
#     Using the feature property, we can extract this set and generate a GeoJSON feature
#     object for each country.
#
# **kwargs :
#     additional keywords passed to TopoDataFormat
# File:      c:\programdata\anaconda3\lib\site-packages\altair\vegalite\v3\api.py
# Type:      function
